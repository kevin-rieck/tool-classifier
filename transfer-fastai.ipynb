# %% [markdown]
# __activate fastai kernel!__

# %%
# %matplotlib inline

# %%
from fastai import *
from fastai.vision.all import *
from fastai.vision import *

# %%
path = "/home/motoko/python-projects/tool-detect/data"
dls = ImageDataLoaders.from_folder(path, valid_pct=0.2, item_tfms=CropPad(224, pad_mode=PadMode.Border))

# %%
dls.show_batch()

# %%
??cnn_learner

# %%
learn = cnn_learner(dls, mobilenet_v2, metrics=error_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a37d2117456a> in <module>
# ----> 1 learn = cnn_learner(dls, mobilenet_v2, metrics=error_rate)
#
# NameError: name 'mobilenet_v2' is not defined

# %%
learn.fine_tune(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.420253</td>
#       <td>0.433304</td>
#       <td>0.184211</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.344581</td>
#       <td>0.346414</td>
#       <td>0.157895</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.248637</td>
#       <td>0.242846</td>
#       <td>0.078947</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=3.311311302240938e-05, lr_steep=1.0964781722577754e-06)

# %%
learn.fine_tune(4, 1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.004699</td>
#       <td>0.168416</td>
#       <td>0.039474</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.020987</td>
#       <td>0.163262</td>
#       <td>0.039474</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.020320</td>
#       <td>0.170832</td>
#       <td>0.039474</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...

# %%
learn.show_results()

# %%
interp = Interpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,10))
